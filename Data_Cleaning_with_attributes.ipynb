# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipali-Jadhav14/API_CALLING/blob/main/Data_Cleaning_with_attributes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#load dataset:

'''
content/movie_titles_metadata.tsv'
/content/aug_train (1).csv

# %%
'''
will see some parameters used in csv files
'''

# %%
pd.read_csv('/content/movie_titles_metadata.tsv')
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
#sep parameter:

#sep means the symbol used to split the data in the file.

'''
1)Colon-separated file (:)
2)sep="--")
3)Pipe-separated file (|)
4)Multiple spaces as separator

If data is separated by many spaces:
  pd.read_csv("data.txt", sep="\s+")

5)Comma-separated file (Default)
'''


pd.read_csv('/content/movie_titles_metadata.tsv',sep='\t')
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2418157317.py:12: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_csv("data.txt", sep="\s+")
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
# ...

# %%
#names:
pd.read_csv('/content/movie_titles_metadata.tsv',sep='\t',names=['SNO','Names','Released_date','rating','votes','genre'])
# Out:
#       SNO                       Names Released_date  rating     votes  \
# 0      m0  10 things i hate about you          1999     6.9   62847.0
# 1      m1  1492: conquest of paradise          1992     6.2   10421.0
# 2      m2                  15 minutes          2001     6.1   25854.0
# 3      m3       2001: a space odyssey          1968     8.4  163227.0
# 4      m4                     48 hrs.          1982     6.9   22289.0
# ..    ...                         ...           ...     ...       ...
# 612  m612                    watchmen          2009     7.8  135229.0
# 613  m613                         xxx          2002     5.6   53505.0
# 614  m614                       x-men          2000     7.4  122149.0
# 615  m615          young frankenstein          1974     8.0   57618.0
# 616  m616                   zulu dawn          1979     6.4    1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# ...

# %%
pd.read_csv('/content/aug_train (1).csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#index_col parameter:

#tells pandas which column should be used as the index

pd.read_csv('/content/aug_train (1).csv',index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
#Header parameter:  (IMP)
#First row contains column names (default)
#Tell pandas to NOT treat any row as header:

pd.read_csv('/content/test.csv')
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.read_csv('/content/test.csv',header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
#use_col parameter:
#Which columns you want to read from the file
#It helps you load only selected columns, instead of loading the entire file.

pd.read_csv('/content/aug_train (1).csv',usecols=['enrollee_id','gender','education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %%
#sqeeze parameter:
#used to convert a DataFrame with one column into a Series automatically.

ser = pd.read_csv('/content/aug_train (1).csv', usecols=['gender']).squeeze("columns")
print(ser)
type(ser)
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object
# pandas.core.series.Series

# %%
#skip_rows/nrows:
#used to skip specific rows while reading a file

pd.read_csv('/content/aug_train (1).csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('/content/aug_train (1).csv',skiprows=[0,1])
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1      33241  city_115               0.789   NaN   No relevent experience
# 2        666  city_162               0.767  Male  Has relevent experience
# 3      21651  city_176               0.764   NaN  Has relevent experience
# 4      28806  city_160               0.920  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19151   7386  city_173               0.878  Male   No relevent experience
# 19152  31398  city_103               0.920  Male  Has relevent experience
# 19153  24576  city_103               0.920  Male  Has relevent experience
# 19154   5756   city_65               0.802  Male  Has relevent experience
# 19155  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %%
#used to read only a limited number of rows from the file.

pd.read_csv('/content/aug_train (1).csv',nrows=50)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# ...

# %%
'''
Categorical Encoding Methods

Common Encodings Used

1️UTF-8 (most common, default)

Latin-1 (ISO-8859-1) (avoids many errors)

cp1252 (Windows encoding)

UTF-16 / UTF-32 (for some text-heavy files)
'''

# %%
#encoding parameter:

#how the text in the file is stored (character format/language format).
import pandas as pd

pd.read_csv('/content/zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2069423380.py in <cell line: 0>()
#       4 import pandas as pd
#       5
# ----> 6 pd.read_csv('/content/zomato.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
pd.read_csv('/content/zomato.csv',encoding='latin_1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
import pandas as pd

# %%
#dtype:
#Dtype: set the data type of one or more columns while reading a file

pd.read_csv('/content/aug_train (1).csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('/content/aug_train (1).csv',dtype={'target':int})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#handling dates:
import pandas as pd

#convert a column (or multiple columns) into proper datetime format while reading the file.
pd.read_csv('/content/IPL Matches 2008-2020.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('/content/IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
#convertor:
#change / modify / clean / format a column as it is being loaded.
pd.read_csv('/content/IPL Matches 2008-2020.csv')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
def rename(name):
  if name=='Royal Challengers Bangalore':
    return "RCB"
  else:
    return name
rename('Royal Challengers Bangalore')
# Out:
# 'RCB'

# %%
pd.read_csv('/content/IPL Matches 2008-2020.csv',converters={'team1':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
#working with Excel file:
import pandas as pd
pd.read_excel('/content/Output.xlsx')
# Out:
#    Rno   Name
# 0    1    Jay
# 1    2    Raj
# 2    3  Baman
# 3    4   Saya
# 4    5    Sai

# %%
import pandas as pd
#To remove 0th index column from dataset we use index_col parameter
df = pd.read_excel('/content/Output.xlsx', index_col=0)

# %%
df
# Out:
#       Name
# Rno
# 1      Jay
# 2      Raj
# 3    Baman
# 4     Saya
# 5      Sai

# %%
#To load next/another sheet data we use seetname parameter....by default it will open sheet1..To open another sheet within same excel file pass
#parameter sheet_name
pd.read_excel('/content/Output.xlsx',sheet_name='Sheet2')
# Out:
#    Cid Cname
# 0  101     A
# 1  102     B
# 2  103     C

# %%
#chunksize:It loads the file piece-by-piece, not all rows together.

dff=pd.read_csv('/content/aug_train.csv',chunksize=5)

dff

# %%
for chunks in dff:
  print(chunks.shape)
# Out:
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# (5, 14)
# ...

# %%
pd.read_csv('/content/question_bank.tsv')
# Out:
#                                   question_id\tquestion
# 0                                              Q00001\t
# 1     Q00002\ta total cholesterol of 180 to 200 mgdl...
# 2     Q00003\tabout how many years experience do you...
# 3     Q00004\taccording to anima the bible or what o...
# 4     Q00005\tae you looking for examples of septic ...
# ...                                                 ...
# 3936  Q03937\twould you want to buy flame design sti...
# 3937  Q03938\twould you want to know about ron howar...
# 3938  Q03939\twould you want to know credit report s...
# 3939  Q03940\twould you want to know what is in a cr...
# 3940  Q03941\twould you wanting to know how to set o...
#
# [3941 rows x 1 columns]

# %%
#read text files:
pd.read_csv('/content/question_bank.tsv',sep='\t')
# Out:
#      question_id                                           question
# 0         Q00001                                                NaN
# 1         Q00002  a total cholesterol of 180 to 200 mgdl 10 to 1...
# 2         Q00003  about how many years experience do you want th...
# 3         Q00004  according to anima the bible or what other source
# 4         Q00005  ae you looking for examples of septic system d...
# ...          ...                                                ...
# 3936      Q03937        would you want to buy flame design stickers
# 3937      Q03938  would you want to know about ron howards actin...
# 3938      Q03939        would you want to know credit report scores
# 3939      Q03940  would you want to know what is in a credit report
# 3940      Q03941        would you wanting to know how to set one up
#
# [3941 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_json('/content/train.json')   # For Colab
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
'''
Pandas Export:
•	to cvs
•	to excel
•	to html
•	to json
•	to sql


'''
# Out:
# '\nPandas Export:\n•\tto cvs\n•\tto excel\n•\tto html\n•\tto json\n•\tto sql\n\n\n'

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-863703626.py in <cell line: 0>()
#       1 #to_csv:
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('deliveries.csv')#it creates empty dataframe
#       4
#       5 df.head()
#
# ...

# %%
#to_csv:
import pandas as pd
df=pd.read_csv('deliveries.csv')#it creates empty dataframe

df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-2631579090.py in <cell line: 0>()
#       1 #to_csv:
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('deliveries.csv')#it creates empty dataframe
#       4
#       5 df.head()
#
# ...
